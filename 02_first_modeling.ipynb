# %% [markdown]
# # 데이터 불러오기

# %%
import pandas as pd
import numpy as np

# %%
full = pd.read_csv("C:\\Users\\user\\Desktop\\중간프로젝트\\의료패널 데이터\\a.csv")

# %%
full.shape
# Out:
# (4934, 160)

# %%
full["PHI_BENEFIT"] = np.exp(full["PHI_BENEFIT"])-1

# %%
full[["PIDWON", "PHI_BENEFIT"]].sort_values("PIDWON")
# Out:
#           PIDWON  PHI_BENEFIT
# 0     11200301.0     186070.0
# 1852  11200301.0      60000.0
# 1853  11200302.0    5826420.0
# 1     11200302.0     841460.0
# 2     11201001.0     350000.0
# ...          ...          ...
# 4931  30008504.0     134379.0
# 4932  40000101.0     450000.0
# 1850  40000201.0    2960000.0
# 1851  40000802.0    1400000.0
# 4933  40000802.0     506871.0
#
# [4934 rows x 2 columns]

# %% [markdown]
# # > RandomForestRegressor

# %%
# 전체 데이터
data = full.copy()

# %% [markdown]
# ## 1. 데이터 분할

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    data.drop("PHI_BENEFIT", axis=1),
    data["PHI_BENEFIT"],
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# ## 2. 모델 훈련

# %%
from sklearn.ensemble import RandomForestRegressor

# 랜덤 포레스트 회귀 모델 생성
RF = RandomForestRegressor(random_state=42, max_depth=5)

# fit
RF.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=5, random_state=42)

# %% [markdown]
# ## 3. 예측 및 평가

# %%
# 예측
# 학습 데이터에 대한 예측
y_pred_train = RF.predict(X_train)
# 테스트 데이터에 대한 예측
y_pred_test = RF.predict(X_test)

# 평가
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# 훈련 데이터 성능 지표 계산
mse_train = mean_squared_error(y_train, y_pred_train)
rmse_train = np.sqrt(mse_train)
mae_train = mean_absolute_error(y_train, y_pred_train)
r2_train = r2_score(y_train, y_pred_train)
# 테스트 데이터 성능 지표 계산
mse_test = mean_squared_error(y_test, y_pred_test)
rmse_test = np.sqrt(mse_test)
mae_test = mean_absolute_error(y_test, y_pred_test)
r2_test = r2_score(y_test, y_pred_test)
# 결과 출력
print("--- Training Set Performance ---")
print(f"MSE: {mse_train:.4f}")
print(f"RMSE: {rmse_train:.4f}")
print(f"MAE: {mae_train:.4f}")
print(f"R² Score: {r2_train:.4f}\n")
print("--- Test Set Performance ---")
print(f"MSE: {mse_test:.4f}")
print(f"RMSE: {rmse_test:.4f}")
print(f"MAE: {mae_test:.4f}")
print(f"R² Score: {r2_test:.4f}")
# Out:
# --- Training Set Performance ---
# MSE: 1.0812
# RMSE: 1.0398
# MAE: 0.7839
# R² Score: 0.5277
#
# --- Test Set Performance ---
# MSE: 1.2346
# RMSE: 1.1111
# MAE: 0.8221
# R² Score: 0.4722

# %% [markdown]
# # > GradientBoosting

# %%
# 전체 데이터
data = full.copy()

# %% [markdown]
# ## 2. 모델 훈련

# %%
# 모델 객체 생성
from sklearn.ensemble import GradientBoostingRegressor

# n_estimators : 약한 학습기(Weak Learner)의 개수. 학습 횟수 = 경사하강법 수행 횟수
# learning_rate : 학습률. 에러(손실 - Loss)에 대한 가중치의 미분 값을 얼마나 반영할지에 대한 비율
#  - 너무 작으면 가중치의 갱신이 잘 이뤄지지 않는다.
#  - 너무 크면 가중치의 갱신이 폭팔적으로 이뤄져서 에러가 오히려 커질 가능성이 생긴다.
GB = GradientBoostingRegressor(
    max_depth=5,
    random_state=42)

# %%
# 모델 적합
GB.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=5, random_state=42)

# %% [markdown]
# ## 3. 예측 및 평가

# %%
# 예측
# 학습 데이터에 대한 예측
y_pred_train = GB.predict(X_train)
# 테스트 데이터에 대한 예측
y_pred_test = GB.predict(X_test)

# 평가
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# 훈련 데이터 성능 지표 계산
mse_train = mean_squared_error(y_train, y_pred_train)
rmse_train = np.sqrt(mse_train)
mae_train = mean_absolute_error(y_train, y_pred_train)
r2_train = r2_score(y_train, y_pred_train)
# 테스트 데이터 성능 지표 계산
mse_test = mean_squared_error(y_test, y_pred_test)
rmse_test = np.sqrt(mse_test)
mae_test = mean_absolute_error(y_test, y_pred_test)
r2_test = r2_score(y_test, y_pred_test)
# 결과 출력
print("--- Training Set Performance ---")
print(f"MSE: {mse_train:.4f}")
print(f"RMSE: {rmse_train:.4f}")
print(f"MAE: {mae_train:.4f}")
print(f"R² Score: {r2_train:.4f}\n")
print("--- Test Set Performance ---")
print(f"MSE: {mse_test:.4f}")
print(f"RMSE: {rmse_test:.4f}")
print(f"MAE: {mae_test:.4f}")
print(f"R² Score: {r2_test:.4f}")
# Out:
# --- Training Set Performance ---
# MSE: 0.6244
# RMSE: 0.7902
# MAE: 0.5986
# R² Score: 0.7272
#
# --- Test Set Performance ---
# MSE: 1.1619
# RMSE: 1.0779
# MAE: 0.7802
# R² Score: 0.5033

# %% [markdown]
# # > XGB

# %% [markdown]
# ## 2. 모델 훈련

# %%
from xgboost import XGBRegressor

XGB = XGBRegressor(random_state=42, max_depth=3)

XGB.fit(X_train, y_train, verbose=True)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# ## 3. 예측 및 평가

# %%
# 예측
# 학습 데이터에 대한 예측
y_pred_train = XGB.predict(X_train)
# 테스트 데이터에 대한 예측
y_pred_test = XGB.predict(X_test)

# 평가
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# 훈련 데이터 성능 지표 계산
mse_train = mean_squared_error(y_train, y_pred_train)
rmse_train = np.sqrt(mse_train)
mae_train = mean_absolute_error(y_train, y_pred_train)
r2_train = r2_score(y_train, y_pred_train)
# 테스트 데이터 성능 지표 계산
mse_test = mean_squared_error(y_test, y_pred_test)
rmse_test = np.sqrt(mse_test)
mae_test = mean_absolute_error(y_test, y_pred_test)
r2_test = r2_score(y_test, y_pred_test)
# 결과 출력
print("--- Training Set Performance ---")
print(f"MSE: {mse_train:.4f}")
print(f"RMSE: {rmse_train:.4f}")
print(f"MAE: {mae_train:.4f}")
print(f"R² Score: {r2_train:.4f}\n")
print("--- Test Set Performance ---")
print(f"MSE: {mse_test:.4f}")
print(f"RMSE: {rmse_test:.4f}")
print(f"MAE: {mae_test:.4f}")
print(f"R² Score: {r2_test:.4f}")
# Out:
# --- Training Set Performance ---
# MSE: 0.7474
# RMSE: 0.8645
# MAE: 0.6485
# R² Score: 0.6735
#
# --- Test Set Performance ---
# MSE: 1.2133
# RMSE: 1.1015
# MAE: 0.7948
# R² Score: 0.4813

# %% [markdown]
# # > lightGBM

# %%
# 모델 객체 생성
from lightgbm import LGBMRegressor

LGBM = LGBMRegressor(
    objective='regression',
    max_depth=5,
    random_state=42
)

# 모델 적합
LGBM.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005716 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3087
# [LightGBM] [Info] Number of data points in the train set: 3947, number of used features: 124
# [LightGBM] [Info] Start training from score 12.900776
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMRegressor(max_depth=5, objective='regression', random_state=42)

# %%
# 예측
# 학습 데이터에 대한 예측
y_pred_train = LGBM.predict(X_train)
# 테스트 데이터에 대한 예측
y_pred_test = LGBM.predict(X_test)

# 평가
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# 훈련 데이터 성능 지표 계산
mse_train = mean_squared_error(y_train, y_pred_train)
rmse_train = np.sqrt(mse_train)
mae_train = mean_absolute_error(y_train, y_pred_train)
r2_train = r2_score(y_train, y_pred_train)
# 테스트 데이터 성능 지표 계산
mse_test = mean_squared_error(y_test, y_pred_test)
rmse_test = np.sqrt(mse_test)
mae_test = mean_absolute_error(y_test, y_pred_test)
r2_test = r2_score(y_test, y_pred_test)
# 결과 출력
print("--- Training Set Performance ---")
print(f"MSE: {mse_train:.4f}")
print(f"RMSE: {rmse_train:.4f}")
print(f"MAE: {mae_train:.4f}")
print(f"R² Score: {r2_train:.4f}\n")
print("--- Test Set Performance ---")
print(f"MSE: {mse_test:.4f}")
print(f"RMSE: {rmse_test:.4f}")
print(f"MAE: {mae_test:.4f}")
print(f"R² Score: {r2_test:.4f}")
# Out:
# --- Training Set Performance ---
# MSE: 0.7170
# RMSE: 0.8468
# MAE: 0.6257
# R² Score: 0.6868
#
# --- Test Set Performance ---
# MSE: 1.1399
# RMSE: 1.0677
# MAE: 0.7817
# R² Score: 0.5127

# %% [markdown]
# # > CatBoost

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp312-cp312-win_amd64.whl.metadata (1.2 kB)
# Collecting graphviz (from catboost)
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (from catboost) (3.9.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\users\user\anaconda3\lib\site-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in c:\users\user\anaconda3\lib\site-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in c:\users\user\anaconda3\lib\site-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->catboost) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->catboost) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from plotly->catboost) (8.2.3)
# Downloading catboost-1.2.7-cp312-cp312-win_amd64.whl (101.7 MB)
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#     --------------------------------------- 1.8/101.7 MB 9.1 MB/s eta 0:00:11
#    - -------------------------------------- 2.9/101.7 MB 6.7 MB/s eta 0:00:15
#    - -------------------------------------- 4.2/101.7 MB 7.2 MB/s eta 0:00:14
#    - -------------------------------------- 5.0/101.7 MB 6.0 MB/s eta 0:00:17
#    -- ------------------------------------- 6.0/101.7 MB 5.8 MB/s eta 0:00:17
#    -- ------------------------------------- 7.6/101.7 MB 5.9 MB/s eta 0:00:16
#    --- ------------------------------------ 8.4/101.7 MB 5.7 MB/s eta 0:00:17
#    --- ------------------------------------ 9.4/101.7 MB 5.6 MB/s eta 0:00:17
#    ---- ----------------------------------- 11.0/101.7 MB 5.8 MB/s eta 0:00:16
#    ---- ----------------------------------- 12.6/101.7 MB 6.0 MB/s eta 0:00:15
#    ----- ---------------------------------- 13.6/101.7 MB 5.8 MB/s eta 0:00:16
#    ----- ---------------------------------- 14.4/101.7 MB 5.7 MB/s eta 0:00:16
#    ------ --------------------------------- 15.7/101.7 MB 5.8 MB/s eta 0:00:15
#    ------ --------------------------------- 17.0/101.7 MB 5.7 MB/s eta 0:00:15
#    ------- -------------------------------- 18.4/101.7 MB 5.8 MB/s eta 0:00:15
#    ------- -------------------------------- 19.4/101.7 MB 5.8 MB/s eta 0:00:15
#    -------- ------------------------------- 20.4/101.7 MB 5.7 MB/s eta 0:00:15
#    -------- ------------------------------- 22.0/101.7 MB 5.8 MB/s eta 0:00:14
#    --------- ------------------------------ 23.6/101.7 MB 5.9 MB/s eta 0:00:14
#    --------- ------------------------------ 24.6/101.7 MB 5.8 MB/s eta 0:00:14
#    ---------- ----------------------------- 26.0/101.7 MB 5.9 MB/s eta 0:00:13
#    ---------- ----------------------------- 27.0/101.7 MB 5.8 MB/s eta 0:00:13
#    ----------- ---------------------------- 28.6/101.7 MB 5.9 MB/s eta 0:00:13
#    ----------- ---------------------------- 30.1/101.7 MB 6.0 MB/s eta 0:00:12
#    ------------ --------------------------- 31.5/101.7 MB 6.0 MB/s eta 0:00:12
#    ------------ --------------------------- 32.2/101.7 MB 5.9 MB/s eta 0:00:12
#    ------------ --------------------------- 33.0/101.7 MB 5.8 MB/s eta 0:00:12
#    ------------- -------------------------- 34.6/101.7 MB 5.9 MB/s eta 0:00:12
#    ------------- -------------------------- 35.4/101.7 MB 5.8 MB/s eta 0:00:12
#    -------------- ------------------------- 37.0/101.7 MB 5.9 MB/s eta 0:00:12
#    -------------- ------------------------- 38.0/101.7 MB 5.8 MB/s eta 0:00:11
#    --------------- ------------------------ 39.1/101.7 MB 5.8 MB/s eta 0:00:11
#    --------------- ------------------------ 40.4/101.7 MB 5.8 MB/s eta 0:00:11
#    ---------------- ----------------------- 41.4/101.7 MB 5.8 MB/s eta 0:00:11
#    ---------------- ----------------------- 42.5/101.7 MB 5.8 MB/s eta 0:00:11
#    ----------------- ---------------------- 43.8/101.7 MB 5.8 MB/s eta 0:00:11
#    ----------------- ---------------------- 44.8/101.7 MB 5.8 MB/s eta 0:00:10
#    ----------------- ---------------------- 45.4/101.7 MB 5.8 MB/s eta 0:00:10
#    ------------------ --------------------- 46.4/101.7 MB 5.7 MB/s eta 0:00:10
#    ------------------ --------------------- 47.4/101.7 MB 5.6 MB/s eta 0:00:10
#    ------------------ --------------------- 48.2/101.7 MB 5.6 MB/s eta 0:00:10
#    ------------------- -------------------- 49.5/101.7 MB 5.6 MB/s eta 0:00:10
#    ------------------- -------------------- 50.3/101.7 MB 5.6 MB/s eta 0:00:10
#    -------------------- ------------------- 51.1/101.7 MB 5.5 MB/s eta 0:00:10
#    -------------------- ------------------- 51.9/101.7 MB 5.5 MB/s eta 0:00:10
#    -------------------- ------------------- 52.4/101.7 MB 5.4 MB/s eta 0:00:10
#    -------------------- ------------------- 53.0/101.7 MB 5.4 MB/s eta 0:00:10
#    --------------------- ------------------ 54.0/101.7 MB 5.3 MB/s eta 0:00:09
#    --------------------- ------------------ 55.3/101.7 MB 5.4 MB/s eta 0:00:09
#    ---------------------- ----------------- 56.1/101.7 MB 5.3 MB/s eta 0:00:09
#    ---------------------- ----------------- 56.9/101.7 MB 5.3 MB/s eta 0:00:09
#    ---------------------- ----------------- 57.4/101.7 MB 5.2 MB/s eta 0:00:09
#    ---------------------- ----------------- 57.9/101.7 MB 5.2 MB/s eta 0:00:09
#    ---------------------- ----------------- 57.9/101.7 MB 5.2 MB/s eta 0:00:09
#    ----------------------- ---------------- 58.7/101.7 MB 5.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 59.5/101.7 MB 5.1 MB/s eta 0:00:09
#    ----------------------- ---------------- 60.3/101.7 MB 5.0 MB/s eta 0:00:09
#    ------------------------ --------------- 61.3/101.7 MB 5.0 MB/s eta 0:00:09
#    ------------------------ --------------- 62.4/101.7 MB 5.0 MB/s eta 0:00:08
#    ------------------------ --------------- 63.2/101.7 MB 5.0 MB/s eta 0:00:08
#    ------------------------- -------------- 63.7/101.7 MB 5.0 MB/s eta 0:00:08
#    ------------------------- -------------- 64.5/101.7 MB 4.9 MB/s eta 0:00:08
#    ------------------------- -------------- 65.3/101.7 MB 4.9 MB/s eta 0:00:08
#    -------------------------- ------------- 66.3/101.7 MB 4.9 MB/s eta 0:00:08
#    -------------------------- ------------- 67.6/101.7 MB 4.9 MB/s eta 0:00:07
#    --------------------------- ------------ 68.7/101.7 MB 4.9 MB/s eta 0:00:07
#    --------------------------- ------------ 70.0/101.7 MB 5.0 MB/s eta 0:00:07
#    --------------------------- ------------ 70.8/101.7 MB 4.9 MB/s eta 0:00:07
#    ---------------------------- ----------- 71.6/101.7 MB 4.9 MB/s eta 0:00:07
#    ---------------------------- ----------- 72.9/101.7 MB 4.9 MB/s eta 0:00:06
#    ----------------------------- ---------- 73.9/101.7 MB 5.0 MB/s eta 0:00:06
#    ----------------------------- ---------- 75.2/101.7 MB 5.0 MB/s eta 0:00:06
#    ----------------------------- ---------- 75.8/101.7 MB 4.9 MB/s eta 0:00:06
#    ------------------------------ --------- 77.3/101.7 MB 5.0 MB/s eta 0:00:05
#    ------------------------------ --------- 78.4/101.7 MB 5.0 MB/s eta 0:00:05
#    ------------------------------- -------- 79.2/101.7 MB 4.9 MB/s eta 0:00:05
#    ------------------------------- -------- 80.2/101.7 MB 4.9 MB/s eta 0:00:05
#    ------------------------------- -------- 80.7/101.7 MB 5.0 MB/s eta 0:00:05
#    -------------------------------- ------- 81.5/101.7 MB 4.9 MB/s eta 0:00:05
#    -------------------------------- ------- 82.6/101.7 MB 4.9 MB/s eta 0:00:04
#    -------------------------------- ------- 83.6/101.7 MB 4.9 MB/s eta 0:00:04
#    --------------------------------- ------ 84.9/101.7 MB 4.9 MB/s eta 0:00:04
#    --------------------------------- ------ 86.0/101.7 MB 4.9 MB/s eta 0:00:04
#    ---------------------------------- ----- 86.8/101.7 MB 4.9 MB/s eta 0:00:04
#    ---------------------------------- ----- 87.8/101.7 MB 4.9 MB/s eta 0:00:03
#    ---------------------------------- ----- 88.6/101.7 MB 4.9 MB/s eta 0:00:03
#    ----------------------------------- ---- 89.4/101.7 MB 4.9 MB/s eta 0:00:03
#    ----------------------------------- ---- 90.2/101.7 MB 4.9 MB/s eta 0:00:03
#    ----------------------------------- ---- 90.7/101.7 MB 4.9 MB/s eta 0:00:03
#    ----------------------------------- ---- 91.5/101.7 MB 4.8 MB/s eta 0:00:03
#    ------------------------------------ --- 92.3/101.7 MB 4.8 MB/s eta 0:00:02
#    ------------------------------------ --- 93.3/101.7 MB 4.8 MB/s eta 0:00:02
#    ------------------------------------ --- 93.8/101.7 MB 4.8 MB/s eta 0:00:02
#    ------------------------------------- -- 94.6/101.7 MB 4.8 MB/s eta 0:00:02
#    ------------------------------------- -- 95.4/101.7 MB 4.8 MB/s eta 0:00:02
#    ------------------------------------- -- 95.9/101.7 MB 4.8 MB/s eta 0:00:02
#    -------------------------------------- - 97.3/101.7 MB 4.8 MB/s eta 0:00:01
#    -------------------------------------- - 97.8/101.7 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  99.4/101.7 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  100.1/101.7 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  101.4/101.7 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  101.7/101.7 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 101.7/101.7 MB 4.7 MB/s eta 0:00:00
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
# Installing collected packages: graphviz, catboost
# Successfully installed catboost-1.2.7 graphviz-0.20.3

# %%
from catboost import CatBoostRegressor

cat = CatBoostRegressor(random_state=42, depth=3)
cat.fit(X_train, y_train)
# Out:
# Learning rate set to 0.050862
# 0:	learn: 1.4886189	total: 1.2ms	remaining: 1.2s
# 1:	learn: 1.4672207	total: 3.9ms	remaining: 1.95s
# 2:	learn: 1.4481963	total: 6.16ms	remaining: 2.05s
# 3:	learn: 1.4294060	total: 7.94ms	remaining: 1.98s
# 4:	learn: 1.4114461	total: 10.2ms	remaining: 2.02s
# 5:	learn: 1.3958309	total: 11.4ms	remaining: 1.9s
# 6:	learn: 1.3806457	total: 12.8ms	remaining: 1.82s
# 7:	learn: 1.3672094	total: 14.3ms	remaining: 1.77s
# 8:	learn: 1.3559338	total: 15.6ms	remaining: 1.72s
# 9:	learn: 1.3440678	total: 16.8ms	remaining: 1.66s
# 10:	learn: 1.3319970	total: 18.4ms	remaining: 1.65s
# 11:	learn: 1.3207409	total: 19.9ms	remaining: 1.64s
# 12:	learn: 1.3110891	total: 21.3ms	remaining: 1.61s
# 13:	learn: 1.3007423	total: 22.6ms	remaining: 1.59s
# 14:	learn: 1.2909399	total: 23.9ms	remaining: 1.57s
# 15:	learn: 1.2822024	total: 25.8ms	remaining: 1.58s
# 16:	learn: 1.2748632	total: 27.2ms	remaining: 1.57s
# 17:	learn: 1.2662244	total: 28.5ms	remaining: 1.55s
# 18:	learn: 1.2588888	total: 29.7ms	remaining: 1.53s
# 19:	learn: 1.2513635	total: 30.9ms	remaining: 1.51s
# 20:	learn: 1.2451038	total: 32.8ms	remaining: 1.53s
# 21:	learn: 1.2398412	total: 34.6ms	remaining: 1.54s
# 22:	learn: 1.2347531	total: 35.8ms	remaining: 1.52s
# 23:	learn: 1.2302865	total: 37ms	remaining: 1.5s
# 24:	learn: 1.2253048	total: 38.5ms	remaining: 1.5s
# 25:	learn: 1.2205823	total: 40.2ms	remaining: 1.5s
# 26:	learn: 1.2168309	total: 41.5ms	remaining: 1.5s
# 27:	learn: 1.2126329	total: 43ms	remaining: 1.49s
# 28:	learn: 1.2084866	total: 44.5ms	remaining: 1.49s
# 29:	learn: 1.2047463	total: 45.9ms	remaining: 1.49s
# 30:	learn: 1.2006986	total: 47.2ms	remaining: 1.48s
# 31:	learn: 1.1975649	total: 48.6ms	remaining: 1.47s
# 32:	learn: 1.1941624	total: 50.2ms	remaining: 1.47s
# 33:	learn: 1.1905373	total: 51.3ms	remaining: 1.46s
# 34:	learn: 1.1871224	total: 52.4ms	remaining: 1.45s
# 35:	learn: 1.1840479	total: 53.7ms	remaining: 1.44s
# 36:	learn: 1.1817723	total: 55ms	remaining: 1.43s
# 37:	learn: 1.1796152	total: 56.2ms	remaining: 1.42s
# 38:	learn: 1.1776642	total: 57.6ms	remaining: 1.42s
# 39:	learn: 1.1753169	total: 59.1ms	remaining: 1.42s
# 40:	learn: 1.1730161	total: 60.4ms	remaining: 1.41s
# 41:	learn: 1.1711417	total: 62.1ms	remaining: 1.42s
# 42:	learn: 1.1690066	total: 63.6ms	remaining: 1.42s
# 43:	learn: 1.1668324	total: 65.2ms	remaining: 1.42s
# 44:	learn: 1.1643904	total: 66.5ms	remaining: 1.41s
# 45:	learn: 1.1625084	total: 67.9ms	remaining: 1.41s
# 46:	learn: 1.1606566	total: 69.2ms	remaining: 1.4s
# 47:	learn: 1.1588737	total: 70.5ms	remaining: 1.4s
# 48:	learn: 1.1571118	total: 72ms	remaining: 1.4s
# 49:	learn: 1.1562232	total: 73.3ms	remaining: 1.39s
# 50:	learn: 1.1544389	total: 74.6ms	remaining: 1.39s
# 51:	learn: 1.1528830	total: 76ms	remaining: 1.39s
# 52:	learn: 1.1509945	total: 77.1ms	remaining: 1.38s
# 53:	learn: 1.1493273	total: 78.4ms	remaining: 1.37s
# 54:	learn: 1.1479939	total: 79.6ms	remaining: 1.37s
# 55:	learn: 1.1469994	total: 80.9ms	remaining: 1.36s
# 56:	learn: 1.1457075	total: 82.2ms	remaining: 1.36s
# 57:	learn: 1.1447374	total: 83.8ms	remaining: 1.36s
# 58:	learn: 1.1435726	total: 85.3ms	remaining: 1.36s
# 59:	learn: 1.1411457	total: 86.7ms	remaining: 1.36s
# 60:	learn: 1.1402592	total: 88.1ms	remaining: 1.35s
# 61:	learn: 1.1392790	total: 89.5ms	remaining: 1.35s
# 62:	learn: 1.1380496	total: 90.8ms	remaining: 1.35s
# 63:	learn: 1.1369035	total: 92ms	remaining: 1.34s
# 64:	learn: 1.1360016	total: 93.1ms	remaining: 1.34s
# 65:	learn: 1.1347953	total: 94.2ms	remaining: 1.33s
# 66:	learn: 1.1337636	total: 95.4ms	remaining: 1.33s
# 67:	learn: 1.1329385	total: 96.6ms	remaining: 1.32s
# 68:	learn: 1.1320489	total: 97.8ms	remaining: 1.32s
# 69:	learn: 1.1309178	total: 99.1ms	remaining: 1.32s
# 70:	learn: 1.1297631	total: 100ms	remaining: 1.31s
# 71:	learn: 1.1291693	total: 102ms	remaining: 1.31s
# 72:	learn: 1.1278185	total: 103ms	remaining: 1.31s
# 73:	learn: 1.1270492	total: 104ms	remaining: 1.3s
# 74:	learn: 1.1262835	total: 105ms	remaining: 1.3s
# 75:	learn: 1.1250419	total: 107ms	remaining: 1.3s
# 76:	learn: 1.1237796	total: 108ms	remaining: 1.29s
# 77:	learn: 1.1228667	total: 109ms	remaining: 1.29s
# 78:	learn: 1.1216737	total: 110ms	remaining: 1.28s
# 79:	learn: 1.1206478	total: 112ms	remaining: 1.28s
# 80:	learn: 1.1199282	total: 113ms	remaining: 1.28s
# 81:	learn: 1.1191656	total: 114ms	remaining: 1.28s
# 82:	learn: 1.1188697	total: 116ms	remaining: 1.28s
# 83:	learn: 1.1181248	total: 117ms	remaining: 1.27s
# 84:	learn: 1.1177624	total: 118ms	remaining: 1.27s
# 85:	learn: 1.1170606	total: 119ms	remaining: 1.27s
# 86:	learn: 1.1164782	total: 121ms	remaining: 1.27s
# 87:	learn: 1.1157913	total: 122ms	remaining: 1.26s
# 88:	learn: 1.1152876	total: 123ms	remaining: 1.26s
# 89:	learn: 1.1147503	total: 125ms	remaining: 1.26s
# 90:	learn: 1.1141193	total: 126ms	remaining: 1.25s
# 91:	learn: 1.1124524	total: 127ms	remaining: 1.25s
# 92:	learn: 1.1120850	total: 128ms	remaining: 1.25s
# 93:	learn: 1.1116000	total: 129ms	remaining: 1.25s
# 94:	learn: 1.1111870	total: 130ms	remaining: 1.24s
# 95:	learn: 1.1107447	total: 131ms	remaining: 1.24s
# 96:	learn: 1.1100076	total: 132ms	remaining: 1.23s
# 97:	learn: 1.1093344	total: 134ms	remaining: 1.23s
# 98:	learn: 1.1084394	total: 135ms	remaining: 1.22s
# 99:	learn: 1.1080934	total: 136ms	remaining: 1.22s
# 100:	learn: 1.1070067	total: 137ms	remaining: 1.22s
# 101:	learn: 1.1066129	total: 138ms	remaining: 1.21s
# 102:	learn: 1.1062019	total: 139ms	remaining: 1.21s
# 103:	learn: 1.1059461	total: 140ms	remaining: 1.21s
# 104:	learn: 1.1054947	total: 141ms	remaining: 1.2s
# 105:	learn: 1.1052558	total: 142ms	remaining: 1.2s
# 106:	learn: 1.1046532	total: 143ms	remaining: 1.19s
# 107:	learn: 1.1042143	total: 144ms	remaining: 1.19s
# 108:	learn: 1.1038485	total: 145ms	remaining: 1.19s
# 109:	learn: 1.1033989	total: 146ms	remaining: 1.18s
# 110:	learn: 1.1028192	total: 147ms	remaining: 1.18s
# 111:	learn: 1.1023104	total: 148ms	remaining: 1.18s
# 112:	learn: 1.1020922	total: 149ms	remaining: 1.17s
# 113:	learn: 1.1012908	total: 150ms	remaining: 1.17s
# 114:	learn: 1.1005904	total: 151ms	remaining: 1.17s
# 115:	learn: 1.1002049	total: 152ms	remaining: 1.16s
# 116:	learn: 1.0998538	total: 153ms	remaining: 1.16s
# 117:	learn: 1.0993534	total: 154ms	remaining: 1.15s
# 118:	learn: 1.0989984	total: 155ms	remaining: 1.15s
# 119:	learn: 1.0986814	total: 157ms	remaining: 1.15s
# 120:	learn: 1.0974999	total: 158ms	remaining: 1.15s
# 121:	learn: 1.0974262	total: 159ms	remaining: 1.14s
# 122:	learn: 1.0967575	total: 160ms	remaining: 1.14s
# 123:	learn: 1.0964013	total: 161ms	remaining: 1.14s
# 124:	learn: 1.0957653	total: 162ms	remaining: 1.13s
# 125:	learn: 1.0951237	total: 163ms	remaining: 1.13s
# 126:	learn: 1.0949636	total: 164ms	remaining: 1.13s
# 127:	learn: 1.0947353	total: 165ms	remaining: 1.12s
# 128:	learn: 1.0940758	total: 166ms	remaining: 1.12s
# 129:	learn: 1.0937353	total: 167ms	remaining: 1.12s
# 130:	learn: 1.0932993	total: 168ms	remaining: 1.12s
# 131:	learn: 1.0929538	total: 170ms	remaining: 1.11s
# 132:	learn: 1.0925227	total: 171ms	remaining: 1.11s
# 133:	learn: 1.0922377	total: 172ms	remaining: 1.11s
# 134:	learn: 1.0918129	total: 173ms	remaining: 1.11s
# 135:	learn: 1.0913024	total: 174ms	remaining: 1.1s
# 136:	learn: 1.0911994	total: 175ms	remaining: 1.1s
# 137:	learn: 1.0909862	total: 176ms	remaining: 1.1s
# 138:	learn: 1.0907662	total: 177ms	remaining: 1.09s
# 139:	learn: 1.0903291	total: 178ms	remaining: 1.09s
# 140:	learn: 1.0900391	total: 179ms	remaining: 1.09s
# 141:	learn: 1.0895817	total: 180ms	remaining: 1.09s
# 142:	learn: 1.0891279	total: 181ms	remaining: 1.08s
# 143:	learn: 1.0888160	total: 182ms	remaining: 1.08s
# 144:	learn: 1.0885997	total: 183ms	remaining: 1.08s
# 145:	learn: 1.0882876	total: 184ms	remaining: 1.08s
# 146:	learn: 1.0881284	total: 185ms	remaining: 1.07s
# 147:	learn: 1.0877802	total: 186ms	remaining: 1.07s
# 148:	learn: 1.0872239	total: 187ms	remaining: 1.07s
# 149:	learn: 1.0869325	total: 188ms	remaining: 1.06s
# 150:	learn: 1.0867484	total: 189ms	remaining: 1.06s
# 151:	learn: 1.0864033	total: 190ms	remaining: 1.06s
# 152:	learn: 1.0856315	total: 191ms	remaining: 1.06s
# 153:	learn: 1.0855480	total: 192ms	remaining: 1.06s
# 154:	learn: 1.0852166	total: 193ms	remaining: 1.05s
# 155:	learn: 1.0849444	total: 194ms	remaining: 1.05s
# 156:	learn: 1.0847519	total: 196ms	remaining: 1.05s
# 157:	learn: 1.0844406	total: 197ms	remaining: 1.05s
# 158:	learn: 1.0839200	total: 198ms	remaining: 1.05s
# 159:	learn: 1.0835790	total: 199ms	remaining: 1.04s
# 160:	learn: 1.0828925	total: 200ms	remaining: 1.04s
# 161:	learn: 1.0820809	total: 201ms	remaining: 1.04s
# 162:	learn: 1.0818130	total: 202ms	remaining: 1.04s
# 163:	learn: 1.0817092	total: 203ms	remaining: 1.03s
# 164:	learn: 1.0815133	total: 204ms	remaining: 1.03s
# 165:	learn: 1.0813452	total: 205ms	remaining: 1.03s
# 166:	learn: 1.0808066	total: 206ms	remaining: 1.03s
# 167:	learn: 1.0804164	total: 207ms	remaining: 1.02s
# 168:	learn: 1.0797993	total: 208ms	remaining: 1.02s
# 169:	learn: 1.0785697	total: 209ms	remaining: 1.02s
# 170:	learn: 1.0785146	total: 210ms	remaining: 1.02s
# 171:	learn: 1.0782569	total: 211ms	remaining: 1.02s
# 172:	learn: 1.0778895	total: 212ms	remaining: 1.01s
# 173:	learn: 1.0773912	total: 214ms	remaining: 1.01s
# 174:	learn: 1.0772202	total: 215ms	remaining: 1.01s
# 175:	learn: 1.0768327	total: 216ms	remaining: 1.01s
# 176:	learn: 1.0765655	total: 217ms	remaining: 1.01s
# 177:	learn: 1.0762242	total: 218ms	remaining: 1.01s
# 178:	learn: 1.0760009	total: 220ms	remaining: 1.01s
# 179:	learn: 1.0757922	total: 221ms	remaining: 1s
# 180:	learn: 1.0756569	total: 222ms	remaining: 1s
# 181:	learn: 1.0755107	total: 223ms	remaining: 1s
# 182:	learn: 1.0748411	total: 224ms	remaining: 1s
# 183:	learn: 1.0746741	total: 225ms	remaining: 999ms
# 184:	learn: 1.0745337	total: 226ms	remaining: 997ms
# 185:	learn: 1.0744303	total: 227ms	remaining: 995ms
# 186:	learn: 1.0742965	total: 228ms	remaining: 993ms
# 187:	learn: 1.0741654	total: 230ms	remaining: 992ms
# 188:	learn: 1.0740255	total: 231ms	remaining: 989ms
# 189:	learn: 1.0735344	total: 232ms	remaining: 987ms
# 190:	learn: 1.0727936	total: 233ms	remaining: 986ms
# 191:	learn: 1.0724090	total: 234ms	remaining: 984ms
# 192:	learn: 1.0719263	total: 235ms	remaining: 982ms
# 193:	learn: 1.0712183	total: 236ms	remaining: 981ms
# 194:	learn: 1.0710951	total: 237ms	remaining: 979ms
# 195:	learn: 1.0707109	total: 238ms	remaining: 978ms
# 196:	learn: 1.0703606	total: 239ms	remaining: 976ms
# 197:	learn: 1.0700599	total: 241ms	remaining: 974ms
# 198:	learn: 1.0696867	total: 242ms	remaining: 973ms
# 199:	learn: 1.0694490	total: 243ms	remaining: 971ms
# 200:	learn: 1.0693420	total: 244ms	remaining: 969ms
# 201:	learn: 1.0692273	total: 245ms	remaining: 967ms
# 202:	learn: 1.0691188	total: 246ms	remaining: 967ms
# 203:	learn: 1.0688610	total: 248ms	remaining: 966ms
# 204:	learn: 1.0687573	total: 249ms	remaining: 965ms
# 205:	learn: 1.0685027	total: 250ms	remaining: 963ms
# 206:	learn: 1.0683862	total: 251ms	remaining: 961ms
# 207:	learn: 1.0680955	total: 252ms	remaining: 960ms
# 208:	learn: 1.0678160	total: 253ms	remaining: 958ms
# 209:	learn: 1.0673710	total: 254ms	remaining: 957ms
# 210:	learn: 1.0672734	total: 256ms	remaining: 956ms
# 211:	learn: 1.0670179	total: 257ms	remaining: 954ms
# 212:	learn: 1.0665861	total: 258ms	remaining: 953ms
# 213:	learn: 1.0662953	total: 259ms	remaining: 952ms
# 214:	learn: 1.0662044	total: 260ms	remaining: 950ms
# 215:	learn: 1.0661263	total: 261ms	remaining: 948ms
# 216:	learn: 1.0656974	total: 262ms	remaining: 947ms
# 217:	learn: 1.0648413	total: 264ms	remaining: 945ms
# 218:	learn: 1.0647470	total: 265ms	remaining: 944ms
# 219:	learn: 1.0646551	total: 266ms	remaining: 943ms
# 220:	learn: 1.0645522	total: 267ms	remaining: 941ms
# 221:	learn: 1.0640682	total: 268ms	remaining: 940ms
# 222:	learn: 1.0631885	total: 269ms	remaining: 939ms
# 223:	learn: 1.0628900	total: 271ms	remaining: 937ms
# 224:	learn: 1.0621064	total: 272ms	remaining: 936ms
# 225:	learn: 1.0620184	total: 273ms	remaining: 934ms
# 226:	learn: 1.0615601	total: 274ms	remaining: 932ms
# 227:	learn: 1.0611659	total: 275ms	remaining: 931ms
# 228:	learn: 1.0610799	total: 276ms	remaining: 929ms
# 229:	learn: 1.0604303	total: 277ms	remaining: 927ms
# 230:	learn: 1.0602873	total: 278ms	remaining: 925ms
# 231:	learn: 1.0599318	total: 279ms	remaining: 923ms
# 232:	learn: 1.0594584	total: 280ms	remaining: 921ms
# 233:	learn: 1.0591093	total: 281ms	remaining: 920ms
# 234:	learn: 1.0587463	total: 282ms	remaining: 919ms
# 235:	learn: 1.0583007	total: 283ms	remaining: 917ms
# 236:	learn: 1.0579610	total: 284ms	remaining: 915ms
# 237:	learn: 1.0578903	total: 285ms	remaining: 913ms
# 238:	learn: 1.0578086	total: 286ms	remaining: 911ms
# 239:	learn: 1.0574526	total: 287ms	remaining: 910ms
# 240:	learn: 1.0573782	total: 288ms	remaining: 908ms
# 241:	learn: 1.0570585	total: 290ms	remaining: 907ms
# 242:	learn: 1.0569864	total: 291ms	remaining: 905ms
# 243:	learn: 1.0568968	total: 292ms	remaining: 904ms
# 244:	learn: 1.0566432	total: 293ms	remaining: 902ms
# 245:	learn: 1.0563514	total: 294ms	remaining: 901ms
# 246:	learn: 1.0560282	total: 295ms	remaining: 900ms
# 247:	learn: 1.0557080	total: 296ms	remaining: 898ms
# 248:	learn: 1.0556442	total: 297ms	remaining: 896ms
# 249:	learn: 1.0555584	total: 298ms	remaining: 894ms
# 250:	learn: 1.0552500	total: 299ms	remaining: 893ms
# 251:	learn: 1.0549286	total: 300ms	remaining: 891ms
# 252:	learn: 1.0545905	total: 301ms	remaining: 890ms
# 253:	learn: 1.0539398	total: 302ms	remaining: 888ms
# 254:	learn: 1.0537343	total: 303ms	remaining: 886ms
# 255:	learn: 1.0536734	total: 304ms	remaining: 884ms
# 256:	learn: 1.0529492	total: 305ms	remaining: 883ms
# 257:	learn: 1.0524082	total: 306ms	remaining: 881ms
# 258:	learn: 1.0517165	total: 307ms	remaining: 879ms
# 259:	learn: 1.0513693	total: 308ms	remaining: 878ms
# 260:	learn: 1.0512981	total: 309ms	remaining: 876ms
# 261:	learn: 1.0511997	total: 311ms	remaining: 875ms
# 262:	learn: 1.0508371	total: 312ms	remaining: 873ms
# 263:	learn: 1.0507788	total: 313ms	remaining: 872ms
# 264:	learn: 1.0507215	total: 314ms	remaining: 871ms
# 265:	learn: 1.0504162	total: 315ms	remaining: 870ms
# 266:	learn: 1.0501303	total: 316ms	remaining: 868ms
# 267:	learn: 1.0497456	total: 317ms	remaining: 867ms
# 268:	learn: 1.0494396	total: 318ms	remaining: 865ms
# 269:	learn: 1.0490611	total: 319ms	remaining: 863ms
# 270:	learn: 1.0487718	total: 320ms	remaining: 862ms
# 271:	learn: 1.0481015	total: 321ms	remaining: 860ms
# 272:	learn: 1.0480350	total: 323ms	remaining: 859ms
# 273:	learn: 1.0476070	total: 324ms	remaining: 857ms
# 274:	learn: 1.0473783	total: 325ms	remaining: 856ms
# 275:	learn: 1.0467262	total: 326ms	remaining: 854ms
# 276:	learn: 1.0465237	total: 327ms	remaining: 853ms
# 277:	learn: 1.0464583	total: 328ms	remaining: 851ms
# 278:	learn: 1.0461726	total: 329ms	remaining: 849ms
# 279:	learn: 1.0461141	total: 330ms	remaining: 848ms
# 280:	learn: 1.0460616	total: 331ms	remaining: 846ms
# 281:	learn: 1.0456906	total: 331ms	remaining: 844ms
# 282:	learn: 1.0455394	total: 333ms	remaining: 842ms
# 283:	learn: 1.0451513	total: 334ms	remaining: 841ms
# 284:	learn: 1.0448681	total: 335ms	remaining: 840ms
# 285:	learn: 1.0446399	total: 336ms	remaining: 838ms
# 286:	learn: 1.0443979	total: 337ms	remaining: 837ms
# 287:	learn: 1.0439900	total: 338ms	remaining: 835ms
# 288:	learn: 1.0439176	total: 339ms	remaining: 834ms
# 289:	learn: 1.0433849	total: 340ms	remaining: 833ms
# 290:	learn: 1.0429737	total: 341ms	remaining: 831ms
# 291:	learn: 1.0427480	total: 342ms	remaining: 830ms
# 292:	learn: 1.0426264	total: 343ms	remaining: 828ms
# 293:	learn: 1.0425651	total: 344ms	remaining: 827ms
# 294:	learn: 1.0422144	total: 345ms	remaining: 825ms
# 295:	learn: 1.0417366	total: 346ms	remaining: 824ms
# 296:	learn: 1.0414431	total: 348ms	remaining: 823ms
# 297:	learn: 1.0413830	total: 349ms	remaining: 821ms
# 298:	learn: 1.0407686	total: 350ms	remaining: 819ms
# 299:	learn: 1.0407316	total: 351ms	remaining: 818ms
# 300:	learn: 1.0401757	total: 352ms	remaining: 817ms
# 301:	learn: 1.0399364	total: 353ms	remaining: 816ms
# 302:	learn: 1.0396119	total: 354ms	remaining: 814ms
# 303:	learn: 1.0391392	total: 355ms	remaining: 813ms
# 304:	learn: 1.0391036	total: 356ms	remaining: 811ms
# 305:	learn: 1.0387150	total: 357ms	remaining: 810ms
# 306:	learn: 1.0384152	total: 358ms	remaining: 808ms
# 307:	learn: 1.0383035	total: 359ms	remaining: 807ms
# 308:	learn: 1.0380127	total: 360ms	remaining: 805ms
# 309:	learn: 1.0373196	total: 361ms	remaining: 804ms
# 310:	learn: 1.0372502	total: 362ms	remaining: 802ms
# 311:	learn: 1.0371829	total: 363ms	remaining: 801ms
# 312:	learn: 1.0369077	total: 364ms	remaining: 799ms
# 313:	learn: 1.0366645	total: 365ms	remaining: 798ms
# 314:	learn: 1.0363909	total: 367ms	remaining: 797ms
# 315:	learn: 1.0358299	total: 368ms	remaining: 796ms
# 316:	learn: 1.0357645	total: 369ms	remaining: 794ms
# 317:	learn: 1.0357122	total: 370ms	remaining: 793ms
# 318:	learn: 1.0356681	total: 371ms	remaining: 791ms
# 319:	learn: 1.0354161	total: 372ms	remaining: 790ms
# 320:	learn: 1.0352366	total: 373ms	remaining: 788ms
# 321:	learn: 1.0349948	total: 374ms	remaining: 787ms
# 322:	learn: 1.0345832	total: 375ms	remaining: 785ms
# 323:	learn: 1.0343033	total: 376ms	remaining: 784ms
# 324:	learn: 1.0342710	total: 377ms	remaining: 782ms
# 325:	learn: 1.0338952	total: 378ms	remaining: 781ms
# 326:	learn: 1.0338465	total: 379ms	remaining: 779ms
# 327:	learn: 1.0335184	total: 380ms	remaining: 778ms
# 328:	learn: 1.0332679	total: 381ms	remaining: 777ms
# 329:	learn: 1.0328491	total: 382ms	remaining: 775ms
# 330:	learn: 1.0326258	total: 383ms	remaining: 774ms
# 331:	learn: 1.0323280	total: 384ms	remaining: 772ms
# 332:	learn: 1.0320746	total: 385ms	remaining: 771ms
# 333:	learn: 1.0317612	total: 386ms	remaining: 770ms
# 334:	learn: 1.0312811	total: 387ms	remaining: 768ms
# 335:	learn: 1.0310314	total: 388ms	remaining: 767ms
# 336:	learn: 1.0309838	total: 389ms	remaining: 765ms
# 337:	learn: 1.0306929	total: 390ms	remaining: 764ms
# 338:	learn: 1.0304482	total: 391ms	remaining: 763ms
# 339:	learn: 1.0299672	total: 392ms	remaining: 761ms
# 340:	learn: 1.0298006	total: 394ms	remaining: 761ms
# 341:	learn: 1.0297118	total: 395ms	remaining: 759ms
# 342:	learn: 1.0296154	total: 396ms	remaining: 758ms
# 343:	learn: 1.0289081	total: 397ms	remaining: 757ms
# 344:	learn: 1.0287926	total: 398ms	remaining: 755ms
# 345:	learn: 1.0287317	total: 399ms	remaining: 754ms
# 346:	learn: 1.0287021	total: 400ms	remaining: 752ms
# 347:	learn: 1.0285613	total: 401ms	remaining: 751ms
# 348:	learn: 1.0283815	total: 402ms	remaining: 749ms
# 349:	learn: 1.0279503	total: 403ms	remaining: 748ms
# 350:	learn: 1.0275920	total: 404ms	remaining: 747ms
# 351:	learn: 1.0274321	total: 405ms	remaining: 745ms
# 352:	learn: 1.0272227	total: 406ms	remaining: 744ms
# 353:	learn: 1.0269403	total: 407ms	remaining: 743ms
# 354:	learn: 1.0262990	total: 408ms	remaining: 742ms
# 355:	learn: 1.0259113	total: 409ms	remaining: 740ms
# 356:	learn: 1.0256769	total: 410ms	remaining: 739ms
# 357:	learn: 1.0256169	total: 411ms	remaining: 738ms
# 358:	learn: 1.0253879	total: 413ms	remaining: 737ms
# 359:	learn: 1.0251964	total: 414ms	remaining: 736ms
# 360:	learn: 1.0251383	total: 415ms	remaining: 734ms
# 361:	learn: 1.0247731	total: 416ms	remaining: 733ms
# 362:	learn: 1.0241355	total: 417ms	remaining: 732ms
# 363:	learn: 1.0241067	total: 418ms	remaining: 730ms
# 364:	learn: 1.0237414	total: 419ms	remaining: 729ms
# 365:	learn: 1.0234302	total: 420ms	remaining: 728ms
# 366:	learn: 1.0228531	total: 421ms	remaining: 727ms
# 367:	learn: 1.0226065	total: 422ms	remaining: 725ms
# 368:	learn: 1.0222091	total: 423ms	remaining: 724ms
# 369:	learn: 1.0221523	total: 424ms	remaining: 722ms
# 370:	learn: 1.0220414	total: 425ms	remaining: 721ms
# 371:	learn: 1.0219553	total: 426ms	remaining: 720ms
# 372:	learn: 1.0215690	total: 427ms	remaining: 718ms
# 373:	learn: 1.0214293	total: 428ms	remaining: 717ms
# 374:	learn: 1.0210922	total: 429ms	remaining: 716ms
# 375:	learn: 1.0209739	total: 430ms	remaining: 714ms
# 376:	learn: 1.0207557	total: 431ms	remaining: 713ms
# 377:	learn: 1.0203648	total: 433ms	remaining: 712ms
# 378:	learn: 1.0201027	total: 433ms	remaining: 710ms
# 379:	learn: 1.0197581	total: 435ms	remaining: 709ms
# 380:	learn: 1.0192898	total: 436ms	remaining: 708ms
# 381:	learn: 1.0192353	total: 437ms	remaining: 707ms
# 382:	learn: 1.0188868	total: 438ms	remaining: 706ms
# 383:	learn: 1.0186785	total: 439ms	remaining: 705ms
# 384:	learn: 1.0186295	total: 440ms	remaining: 703ms
# 385:	learn: 1.0185353	total: 441ms	remaining: 702ms
# 386:	learn: 1.0181690	total: 442ms	remaining: 701ms
# 387:	learn: 1.0179228	total: 443ms	remaining: 699ms
# 388:	learn: 1.0178589	total: 444ms	remaining: 698ms
# 389:	learn: 1.0174479	total: 445ms	remaining: 697ms
# 390:	learn: 1.0172659	total: 446ms	remaining: 695ms
# 391:	learn: 1.0171306	total: 447ms	remaining: 694ms
# 392:	learn: 1.0167639	total: 448ms	remaining: 692ms
# 393:	learn: 1.0167357	total: 449ms	remaining: 691ms
# 394:	learn: 1.0165485	total: 450ms	remaining: 690ms
# 395:	learn: 1.0161499	total: 452ms	remaining: 689ms
# 396:	learn: 1.0161226	total: 453ms	remaining: 688ms
# 397:	learn: 1.0159952	total: 454ms	remaining: 686ms
# 398:	learn: 1.0156279	total: 455ms	remaining: 685ms
# 399:	learn: 1.0150469	total: 456ms	remaining: 684ms
# 400:	learn: 1.0147097	total: 457ms	remaining: 682ms
# 401:	learn: 1.0144639	total: 458ms	remaining: 681ms
# 402:	learn: 1.0142035	total: 459ms	remaining: 680ms
# 403:	learn: 1.0137498	total: 460ms	remaining: 678ms
# 404:	learn: 1.0135424	total: 461ms	remaining: 677ms
# 405:	learn: 1.0133597	total: 462ms	remaining: 676ms
# 406:	learn: 1.0128308	total: 463ms	remaining: 675ms
# 407:	learn: 1.0123857	total: 464ms	remaining: 674ms
# 408:	learn: 1.0122250	total: 466ms	remaining: 673ms
# 409:	learn: 1.0119330	total: 467ms	remaining: 672ms
# 410:	learn: 1.0116106	total: 468ms	remaining: 671ms
# 411:	learn: 1.0112096	total: 469ms	remaining: 669ms
# 412:	learn: 1.0106291	total: 470ms	remaining: 668ms
# 413:	learn: 1.0104179	total: 471ms	remaining: 667ms
# 414:	learn: 1.0101503	total: 472ms	remaining: 666ms
# 415:	learn: 1.0098826	total: 473ms	remaining: 665ms
# 416:	learn: 1.0097616	total: 474ms	remaining: 663ms
# 417:	learn: 1.0094849	total: 475ms	remaining: 662ms
# 418:	learn: 1.0091790	total: 476ms	remaining: 660ms
# 419:	learn: 1.0089011	total: 477ms	remaining: 659ms
# 420:	learn: 1.0088683	total: 478ms	remaining: 658ms
# 421:	learn: 1.0082771	total: 479ms	remaining: 657ms
# 422:	learn: 1.0080597	total: 480ms	remaining: 655ms
# 423:	learn: 1.0078723	total: 481ms	remaining: 654ms
# 424:	learn: 1.0078456	total: 482ms	remaining: 653ms
# 425:	learn: 1.0078078	total: 483ms	remaining: 651ms
# 426:	learn: 1.0072938	total: 485ms	remaining: 650ms
# 427:	learn: 1.0071817	total: 486ms	remaining: 649ms
# 428:	learn: 1.0069589	total: 487ms	remaining: 648ms
# 429:	learn: 1.0069334	total: 488ms	remaining: 646ms
# 430:	learn: 1.0068620	total: 489ms	remaining: 645ms
# 431:	learn: 1.0066260	total: 490ms	remaining: 644ms
# 432:	learn: 1.0062490	total: 491ms	remaining: 643ms
# 433:	learn: 1.0061906	total: 492ms	remaining: 642ms
# 434:	learn: 1.0058397	total: 493ms	remaining: 640ms
# 435:	learn: 1.0057946	total: 494ms	remaining: 639ms
# 436:	learn: 1.0054749	total: 495ms	remaining: 638ms
# 437:	learn: 1.0054387	total: 496ms	remaining: 637ms
# 438:	learn: 1.0053969	total: 498ms	remaining: 636ms
# 439:	learn: 1.0053620	total: 499ms	remaining: 635ms
# 440:	learn: 1.0051579	total: 500ms	remaining: 633ms
# 441:	learn: 1.0049513	total: 501ms	remaining: 632ms
# 442:	learn: 1.0045312	total: 502ms	remaining: 631ms
# 443:	learn: 1.0043281	total: 503ms	remaining: 629ms
# 444:	learn: 1.0040757	total: 504ms	remaining: 628ms
# 445:	learn: 1.0038405	total: 505ms	remaining: 627ms
# 446:	learn: 1.0036195	total: 506ms	remaining: 626ms
# 447:	learn: 1.0033571	total: 507ms	remaining: 624ms
# 448:	learn: 1.0031739	total: 508ms	remaining: 623ms
# 449:	learn: 1.0031402	total: 509ms	remaining: 622ms
# 450:	learn: 1.0029430	total: 510ms	remaining: 621ms
# 451:	learn: 1.0024192	total: 511ms	remaining: 620ms
# 452:	learn: 1.0020712	total: 512ms	remaining: 618ms
# 453:	learn: 1.0018232	total: 513ms	remaining: 617ms
# 454:	learn: 1.0015088	total: 514ms	remaining: 616ms
# 455:	learn: 1.0011811	total: 515ms	remaining: 615ms
# 456:	learn: 1.0009236	total: 516ms	remaining: 613ms
# 457:	learn: 1.0008904	total: 517ms	remaining: 612ms
# 458:	learn: 1.0008612	total: 518ms	remaining: 611ms
# 459:	learn: 1.0004084	total: 519ms	remaining: 610ms
# 460:	learn: 1.0001780	total: 520ms	remaining: 608ms
# 461:	learn: 0.9997495	total: 521ms	remaining: 607ms
# 462:	learn: 0.9993344	total: 522ms	remaining: 606ms
# 463:	learn: 0.9990398	total: 524ms	remaining: 605ms
# 464:	learn: 0.9988086	total: 525ms	remaining: 604ms
# 465:	learn: 0.9985747	total: 526ms	remaining: 602ms
# 466:	learn: 0.9984631	total: 527ms	remaining: 601ms
# 467:	learn: 0.9982776	total: 528ms	remaining: 600ms
# 468:	learn: 0.9980718	total: 529ms	remaining: 598ms
# 469:	learn: 0.9978692	total: 530ms	remaining: 597ms
# 470:	learn: 0.9975529	total: 531ms	remaining: 596ms
# 471:	learn: 0.9971657	total: 532ms	remaining: 595ms
# 472:	learn: 0.9969585	total: 533ms	remaining: 594ms
# 473:	learn: 0.9969257	total: 534ms	remaining: 592ms
# 474:	learn: 0.9964575	total: 535ms	remaining: 591ms
# 475:	learn: 0.9959898	total: 536ms	remaining: 590ms
# 476:	learn: 0.9958841	total: 537ms	remaining: 589ms
# 477:	learn: 0.9954675	total: 538ms	remaining: 588ms
# 478:	learn: 0.9952053	total: 539ms	remaining: 586ms
# 479:	learn: 0.9949577	total: 540ms	remaining: 585ms
# 480:	learn: 0.9949139	total: 541ms	remaining: 584ms
# 481:	learn: 0.9944289	total: 542ms	remaining: 583ms
# 482:	learn: 0.9942123	total: 543ms	remaining: 582ms
# 483:	learn: 0.9939604	total: 544ms	remaining: 580ms
# 484:	learn: 0.9935269	total: 545ms	remaining: 579ms
# 485:	learn: 0.9933494	total: 547ms	remaining: 578ms
# 486:	learn: 0.9931880	total: 548ms	remaining: 577ms
# 487:	learn: 0.9929916	total: 549ms	remaining: 576ms
# 488:	learn: 0.9926586	total: 550ms	remaining: 574ms
# 489:	learn: 0.9923996	total: 551ms	remaining: 573ms
# 490:	learn: 0.9920443	total: 552ms	remaining: 572ms
# 491:	learn: 0.9920129	total: 553ms	remaining: 571ms
# 492:	learn: 0.9919908	total: 554ms	remaining: 570ms
# 493:	learn: 0.9918329	total: 555ms	remaining: 568ms
# 494:	learn: 0.9916142	total: 556ms	remaining: 567ms
# 495:	learn: 0.9914296	total: 557ms	remaining: 566ms
# 496:	learn: 0.9912859	total: 558ms	remaining: 565ms
# 497:	learn: 0.9912560	total: 559ms	remaining: 564ms
# 498:	learn: 0.9910505	total: 561ms	remaining: 563ms
# 499:	learn: 0.9909726	total: 562ms	remaining: 562ms
# 500:	learn: 0.9906803	total: 563ms	remaining: 561ms
# 501:	learn: 0.9903794	total: 564ms	remaining: 560ms
# 502:	learn: 0.9901861	total: 565ms	remaining: 559ms
# 503:	learn: 0.9900563	total: 567ms	remaining: 558ms
# 504:	learn: 0.9898883	total: 568ms	remaining: 556ms
# 505:	learn: 0.9896233	total: 569ms	remaining: 556ms
# 506:	learn: 0.9892452	total: 570ms	remaining: 554ms
# 507:	learn: 0.9888667	total: 571ms	remaining: 553ms
# 508:	learn: 0.9887406	total: 573ms	remaining: 552ms
# 509:	learn: 0.9884571	total: 574ms	remaining: 551ms
# 510:	learn: 0.9883075	total: 575ms	remaining: 550ms
# 511:	learn: 0.9881435	total: 576ms	remaining: 549ms
# 512:	learn: 0.9879000	total: 577ms	remaining: 548ms
# 513:	learn: 0.9876157	total: 578ms	remaining: 547ms
# 514:	learn: 0.9874162	total: 579ms	remaining: 546ms
# 515:	learn: 0.9873152	total: 580ms	remaining: 544ms
# 516:	learn: 0.9871619	total: 582ms	remaining: 543ms
# 517:	learn: 0.9870713	total: 583ms	remaining: 542ms
# 518:	learn: 0.9868048	total: 584ms	remaining: 541ms
# 519:	learn: 0.9867621	total: 585ms	remaining: 540ms
# 520:	learn: 0.9865393	total: 586ms	remaining: 539ms
# 521:	learn: 0.9862866	total: 587ms	remaining: 538ms
# 522:	learn: 0.9859489	total: 589ms	remaining: 537ms
# 523:	learn: 0.9858640	total: 590ms	remaining: 536ms
# 524:	learn: 0.9858347	total: 591ms	remaining: 535ms
# 525:	learn: 0.9857475	total: 592ms	remaining: 534ms
# 526:	learn: 0.9854417	total: 594ms	remaining: 533ms
# 527:	learn: 0.9853445	total: 595ms	remaining: 532ms
# 528:	learn: 0.9850722	total: 596ms	remaining: 531ms
# 529:	learn: 0.9849373	total: 597ms	remaining: 529ms
# 530:	learn: 0.9845087	total: 598ms	remaining: 528ms
# 531:	learn: 0.9842702	total: 599ms	remaining: 527ms
# 532:	learn: 0.9841074	total: 600ms	remaining: 526ms
# 533:	learn: 0.9839329	total: 601ms	remaining: 525ms
# 534:	learn: 0.9837408	total: 603ms	remaining: 524ms
# 535:	learn: 0.9834965	total: 604ms	remaining: 523ms
# 536:	learn: 0.9832690	total: 605ms	remaining: 521ms
# 537:	learn: 0.9832320	total: 606ms	remaining: 520ms
# 538:	learn: 0.9829098	total: 607ms	remaining: 519ms
# 539:	learn: 0.9827567	total: 608ms	remaining: 518ms
# 540:	learn: 0.9823951	total: 609ms	remaining: 517ms
# 541:	learn: 0.9823359	total: 611ms	remaining: 516ms
# 542:	learn: 0.9819449	total: 612ms	remaining: 515ms
# 543:	learn: 0.9816754	total: 613ms	remaining: 514ms
# 544:	learn: 0.9814988	total: 614ms	remaining: 512ms
# 545:	learn: 0.9814752	total: 615ms	remaining: 511ms
# 546:	learn: 0.9811163	total: 616ms	remaining: 510ms
# 547:	learn: 0.9807398	total: 617ms	remaining: 509ms
# 548:	learn: 0.9805576	total: 618ms	remaining: 508ms
# 549:	learn: 0.9803927	total: 619ms	remaining: 507ms
# 550:	learn: 0.9803655	total: 620ms	remaining: 506ms
# 551:	learn: 0.9802157	total: 622ms	remaining: 504ms
# 552:	learn: 0.9800340	total: 623ms	remaining: 503ms
# 553:	learn: 0.9796709	total: 624ms	remaining: 502ms
# 554:	learn: 0.9792187	total: 624ms	remaining: 501ms
# 555:	learn: 0.9791597	total: 625ms	remaining: 499ms
# 556:	learn: 0.9788130	total: 626ms	remaining: 498ms
# 557:	learn: 0.9784380	total: 627ms	remaining: 497ms
# 558:	learn: 0.9781953	total: 628ms	remaining: 496ms
# 559:	learn: 0.9781733	total: 629ms	remaining: 494ms
# 560:	learn: 0.9779334	total: 630ms	remaining: 493ms
# 561:	learn: 0.9776549	total: 631ms	remaining: 492ms
# 562:	learn: 0.9773550	total: 632ms	remaining: 491ms
# 563:	learn: 0.9771151	total: 633ms	remaining: 489ms
# 564:	learn: 0.9769511	total: 634ms	remaining: 488ms
# 565:	learn: 0.9768598	total: 635ms	remaining: 487ms
# 566:	learn: 0.9766450	total: 636ms	remaining: 486ms
# 567:	learn: 0.9763912	total: 637ms	remaining: 485ms
# 568:	learn: 0.9763013	total: 638ms	remaining: 483ms
# 569:	learn: 0.9760999	total: 639ms	remaining: 482ms
# 570:	learn: 0.9760731	total: 640ms	remaining: 481ms
# 571:	learn: 0.9758644	total: 641ms	remaining: 479ms
# 572:	learn: 0.9757488	total: 642ms	remaining: 478ms
# 573:	learn: 0.9756196	total: 643ms	remaining: 477ms
# 574:	learn: 0.9754139	total: 644ms	remaining: 476ms
# 575:	learn: 0.9753937	total: 645ms	remaining: 475ms
# 576:	learn: 0.9751853	total: 646ms	remaining: 474ms
# 577:	learn: 0.9750282	total: 647ms	remaining: 472ms
# 578:	learn: 0.9748089	total: 648ms	remaining: 471ms
# 579:	learn: 0.9747733	total: 649ms	remaining: 470ms
# 580:	learn: 0.9746476	total: 650ms	remaining: 469ms
# 581:	learn: 0.9743563	total: 651ms	remaining: 467ms
# 582:	learn: 0.9741271	total: 652ms	remaining: 466ms
# 583:	learn: 0.9741029	total: 653ms	remaining: 465ms
# 584:	learn: 0.9739606	total: 654ms	remaining: 464ms
# 585:	learn: 0.9735763	total: 655ms	remaining: 462ms
# 586:	learn: 0.9735154	total: 655ms	remaining: 461ms
# 587:	learn: 0.9732575	total: 656ms	remaining: 460ms
# 588:	learn: 0.9731097	total: 657ms	remaining: 459ms
# 589:	learn: 0.9730908	total: 658ms	remaining: 457ms
# 590:	learn: 0.9729029	total: 659ms	remaining: 456ms
# 591:	learn: 0.9727310	total: 660ms	remaining: 455ms
# 592:	learn: 0.9724801	total: 661ms	remaining: 454ms
# 593:	learn: 0.9721445	total: 662ms	remaining: 453ms
# 594:	learn: 0.9719304	total: 663ms	remaining: 452ms
# 595:	learn: 0.9719071	total: 664ms	remaining: 450ms
# 596:	learn: 0.9716617	total: 665ms	remaining: 449ms
# 597:	learn: 0.9714969	total: 666ms	remaining: 448ms
# 598:	learn: 0.9714127	total: 668ms	remaining: 447ms
# 599:	learn: 0.9712031	total: 669ms	remaining: 446ms
# 600:	learn: 0.9709375	total: 670ms	remaining: 445ms
# 601:	learn: 0.9709204	total: 671ms	remaining: 443ms
# 602:	learn: 0.9707680	total: 672ms	remaining: 442ms
# 603:	learn: 0.9706395	total: 673ms	remaining: 441ms
# 604:	learn: 0.9702770	total: 673ms	remaining: 440ms
# 605:	learn: 0.9699823	total: 675ms	remaining: 439ms
# 606:	learn: 0.9698310	total: 675ms	remaining: 437ms
# 607:	learn: 0.9696484	total: 676ms	remaining: 436ms
# 608:	learn: 0.9694136	total: 677ms	remaining: 435ms
# 609:	learn: 0.9693404	total: 678ms	remaining: 434ms
# 610:	learn: 0.9689935	total: 679ms	remaining: 432ms
# 611:	learn: 0.9687442	total: 680ms	remaining: 431ms
# 612:	learn: 0.9686396	total: 681ms	remaining: 430ms
# 613:	learn: 0.9685711	total: 682ms	remaining: 429ms
# 614:	learn: 0.9683254	total: 683ms	remaining: 428ms
# 615:	learn: 0.9683093	total: 684ms	remaining: 426ms
# 616:	learn: 0.9678433	total: 685ms	remaining: 425ms
# 617:	learn: 0.9676892	total: 686ms	remaining: 424ms
# 618:	learn: 0.9676494	total: 687ms	remaining: 423ms
# 619:	learn: 0.9674838	total: 688ms	remaining: 422ms
# 620:	learn: 0.9672490	total: 689ms	remaining: 420ms
# 621:	learn: 0.9672282	total: 690ms	remaining: 419ms
# 622:	learn: 0.9670961	total: 691ms	remaining: 418ms
# 623:	learn: 0.9669453	total: 692ms	remaining: 417ms
# 624:	learn: 0.9667560	total: 693ms	remaining: 416ms
# 625:	learn: 0.9667190	total: 694ms	remaining: 415ms
# 626:	learn: 0.9665072	total: 696ms	remaining: 414ms
# 627:	learn: 0.9664111	total: 697ms	remaining: 413ms
# 628:	learn: 0.9663726	total: 698ms	remaining: 411ms
# 629:	learn: 0.9662582	total: 699ms	remaining: 410ms
# 630:	learn: 0.9661627	total: 700ms	remaining: 409ms
# 631:	learn: 0.9658280	total: 701ms	remaining: 408ms
# 632:	learn: 0.9656981	total: 702ms	remaining: 407ms
# 633:	learn: 0.9655185	total: 703ms	remaining: 406ms
# 634:	learn: 0.9654841	total: 704ms	remaining: 404ms
# 635:	learn: 0.9653164	total: 705ms	remaining: 403ms
# 636:	learn: 0.9650116	total: 706ms	remaining: 402ms
# 637:	learn: 0.9648882	total: 707ms	remaining: 401ms
# 638:	learn: 0.9645727	total: 708ms	remaining: 400ms
# 639:	learn: 0.9645447	total: 709ms	remaining: 399ms
# 640:	learn: 0.9642331	total: 710ms	remaining: 397ms
# 641:	learn: 0.9639932	total: 710ms	remaining: 396ms
# 642:	learn: 0.9636495	total: 711ms	remaining: 395ms
# 643:	learn: 0.9635043	total: 712ms	remaining: 394ms
# 644:	learn: 0.9632809	total: 713ms	remaining: 393ms
# 645:	learn: 0.9631185	total: 714ms	remaining: 392ms
# 646:	learn: 0.9628617	total: 716ms	remaining: 390ms
# 647:	learn: 0.9625422	total: 717ms	remaining: 389ms
# 648:	learn: 0.9622973	total: 718ms	remaining: 388ms
# 649:	learn: 0.9620825	total: 719ms	remaining: 387ms
# 650:	learn: 0.9618753	total: 720ms	remaining: 386ms
# 651:	learn: 0.9615803	total: 721ms	remaining: 385ms
# 652:	learn: 0.9613966	total: 722ms	remaining: 384ms
# 653:	learn: 0.9610764	total: 723ms	remaining: 383ms
# 654:	learn: 0.9610546	total: 724ms	remaining: 381ms
# 655:	learn: 0.9609050	total: 725ms	remaining: 380ms
# 656:	learn: 0.9608684	total: 726ms	remaining: 379ms
# 657:	learn: 0.9608422	total: 727ms	remaining: 378ms
# 658:	learn: 0.9605660	total: 728ms	remaining: 377ms
# 659:	learn: 0.9603471	total: 729ms	remaining: 376ms
# 660:	learn: 0.9602131	total: 730ms	remaining: 374ms
# 661:	learn: 0.9599088	total: 731ms	remaining: 373ms
# 662:	learn: 0.9598592	total: 732ms	remaining: 372ms
# 663:	learn: 0.9597037	total: 733ms	remaining: 371ms
# 664:	learn: 0.9595083	total: 734ms	remaining: 370ms
# 665:	learn: 0.9594329	total: 735ms	remaining: 369ms
# 666:	learn: 0.9589747	total: 736ms	remaining: 367ms
# 667:	learn: 0.9589548	total: 737ms	remaining: 366ms
# 668:	learn: 0.9588728	total: 738ms	remaining: 365ms
# 669:	learn: 0.9586995	total: 739ms	remaining: 364ms
# 670:	learn: 0.9584021	total: 740ms	remaining: 363ms
# 671:	learn: 0.9583487	total: 741ms	remaining: 362ms
# 672:	learn: 0.9580963	total: 742ms	remaining: 360ms
# 673:	learn: 0.9580187	total: 743ms	remaining: 359ms
# 674:	learn: 0.9577821	total: 744ms	remaining: 358ms
# 675:	learn: 0.9575927	total: 745ms	remaining: 357ms
# 676:	learn: 0.9575732	total: 746ms	remaining: 356ms
# 677:	learn: 0.9573679	total: 747ms	remaining: 355ms
# 678:	learn: 0.9573037	total: 748ms	remaining: 354ms
# 679:	learn: 0.9571332	total: 749ms	remaining: 352ms
# 680:	learn: 0.9570273	total: 750ms	remaining: 351ms
# 681:	learn: 0.9568742	total: 751ms	remaining: 350ms
# 682:	learn: 0.9566964	total: 752ms	remaining: 349ms
# 683:	learn: 0.9566727	total: 753ms	remaining: 348ms
# 684:	learn: 0.9565619	total: 754ms	remaining: 347ms
# 685:	learn: 0.9563593	total: 755ms	remaining: 346ms
# 686:	learn: 0.9563401	total: 756ms	remaining: 345ms
# 687:	learn: 0.9563269	total: 757ms	remaining: 343ms
# 688:	learn: 0.9562305	total: 759ms	remaining: 342ms
# 689:	learn: 0.9562177	total: 760ms	remaining: 341ms
# 690:	learn: 0.9560587	total: 761ms	remaining: 340ms
# 691:	learn: 0.9560434	total: 762ms	remaining: 339ms
# 692:	learn: 0.9558344	total: 763ms	remaining: 338ms
# 693:	learn: 0.9557001	total: 764ms	remaining: 337ms
# 694:	learn: 0.9555533	total: 765ms	remaining: 336ms
# 695:	learn: 0.9553110	total: 766ms	remaining: 335ms
# 696:	learn: 0.9552891	total: 767ms	remaining: 333ms
# 697:	learn: 0.9551270	total: 768ms	remaining: 332ms
# 698:	learn: 0.9549307	total: 769ms	remaining: 331ms
# 699:	learn: 0.9549138	total: 770ms	remaining: 330ms
# 700:	learn: 0.9548737	total: 771ms	remaining: 329ms
# 701:	learn: 0.9547189	total: 772ms	remaining: 328ms
# 702:	learn: 0.9545866	total: 773ms	remaining: 327ms
# 703:	learn: 0.9542661	total: 774ms	remaining: 325ms
# 704:	learn: 0.9541453	total: 775ms	remaining: 324ms
# 705:	learn: 0.9541048	total: 776ms	remaining: 323ms
# 706:	learn: 0.9540708	total: 777ms	remaining: 322ms
# 707:	learn: 0.9537700	total: 778ms	remaining: 321ms
# 708:	learn: 0.9537577	total: 779ms	remaining: 320ms
# 709:	learn: 0.9537313	total: 780ms	remaining: 318ms
# 710:	learn: 0.9535759	total: 780ms	remaining: 317ms
# 711:	learn: 0.9534160	total: 781ms	remaining: 316ms
# 712:	learn: 0.9531236	total: 782ms	remaining: 315ms
# 713:	learn: 0.9529407	total: 783ms	remaining: 314ms
# 714:	learn: 0.9529274	total: 784ms	remaining: 313ms
# 715:	learn: 0.9524363	total: 785ms	remaining: 311ms
# 716:	learn: 0.9521568	total: 786ms	remaining: 310ms
# 717:	learn: 0.9518497	total: 787ms	remaining: 309ms
# 718:	learn: 0.9516524	total: 788ms	remaining: 308ms
# 719:	learn: 0.9515315	total: 790ms	remaining: 307ms
# 720:	learn: 0.9513880	total: 791ms	remaining: 306ms
# 721:	learn: 0.9511646	total: 792ms	remaining: 305ms
# 722:	learn: 0.9511390	total: 793ms	remaining: 304ms
# 723:	learn: 0.9509065	total: 794ms	remaining: 303ms
# 724:	learn: 0.9506200	total: 795ms	remaining: 301ms
# 725:	learn: 0.9503536	total: 796ms	remaining: 300ms
# 726:	learn: 0.9501657	total: 797ms	remaining: 299ms
# 727:	learn: 0.9498973	total: 798ms	remaining: 298ms
# 728:	learn: 0.9498315	total: 799ms	remaining: 297ms
# 729:	learn: 0.9497776	total: 800ms	remaining: 296ms
# 730:	learn: 0.9496688	total: 801ms	remaining: 295ms
# 731:	learn: 0.9495752	total: 802ms	remaining: 294ms
# 732:	learn: 0.9493496	total: 803ms	remaining: 292ms
# 733:	learn: 0.9490843	total: 804ms	remaining: 291ms
# 734:	learn: 0.9487343	total: 805ms	remaining: 290ms
# 735:	learn: 0.9485161	total: 806ms	remaining: 289ms
# 736:	learn: 0.9484266	total: 807ms	remaining: 288ms
# 737:	learn: 0.9483829	total: 808ms	remaining: 287ms
# 738:	learn: 0.9481895	total: 809ms	remaining: 286ms
# 739:	learn: 0.9480076	total: 810ms	remaining: 285ms
# 740:	learn: 0.9477758	total: 811ms	remaining: 284ms
# 741:	learn: 0.9477463	total: 812ms	remaining: 283ms
# 742:	learn: 0.9477270	total: 814ms	remaining: 281ms
# 743:	learn: 0.9477123	total: 815ms	remaining: 280ms
# 744:	learn: 0.9475810	total: 815ms	remaining: 279ms
# 745:	learn: 0.9473028	total: 816ms	remaining: 278ms
# 746:	learn: 0.9469229	total: 818ms	remaining: 277ms
# 747:	learn: 0.9467675	total: 819ms	remaining: 276ms
# 748:	learn: 0.9465127	total: 820ms	remaining: 275ms
# 749:	learn: 0.9462505	total: 821ms	remaining: 274ms
# 750:	learn: 0.9460849	total: 821ms	remaining: 272ms
# 751:	learn: 0.9459032	total: 822ms	remaining: 271ms
# 752:	learn: 0.9457749	total: 823ms	remaining: 270ms
# 753:	learn: 0.9455978	total: 825ms	remaining: 269ms
# 754:	learn: 0.9455337	total: 826ms	remaining: 268ms
# 755:	learn: 0.9452110	total: 827ms	remaining: 267ms
# 756:	learn: 0.9450830	total: 828ms	remaining: 266ms
# 757:	learn: 0.9448562	total: 829ms	remaining: 265ms
# 758:	learn: 0.9446575	total: 830ms	remaining: 263ms
# 759:	learn: 0.9445219	total: 831ms	remaining: 262ms
# 760:	learn: 0.9442102	total: 832ms	remaining: 261ms
# 761:	learn: 0.9438800	total: 833ms	remaining: 260ms
# 762:	learn: 0.9437150	total: 834ms	remaining: 259ms
# 763:	learn: 0.9434435	total: 835ms	remaining: 258ms
# 764:	learn: 0.9432538	total: 836ms	remaining: 257ms
# 765:	learn: 0.9429774	total: 837ms	remaining: 256ms
# 766:	learn: 0.9428318	total: 838ms	remaining: 255ms
# 767:	learn: 0.9426665	total: 839ms	remaining: 254ms
# 768:	learn: 0.9425318	total: 840ms	remaining: 252ms
# 769:	learn: 0.9423045	total: 841ms	remaining: 251ms
# 770:	learn: 0.9418606	total: 842ms	remaining: 250ms
# 771:	learn: 0.9418178	total: 843ms	remaining: 249ms
# 772:	learn: 0.9417174	total: 844ms	remaining: 248ms
# 773:	learn: 0.9415040	total: 845ms	remaining: 247ms
# 774:	learn: 0.9413842	total: 846ms	remaining: 246ms
# 775:	learn: 0.9410719	total: 847ms	remaining: 245ms
# 776:	learn: 0.9408873	total: 848ms	remaining: 243ms
# 777:	learn: 0.9407812	total: 849ms	remaining: 242ms
# 778:	learn: 0.9407203	total: 850ms	remaining: 241ms
# 779:	learn: 0.9405433	total: 851ms	remaining: 240ms
# 780:	learn: 0.9403163	total: 853ms	remaining: 239ms
# 781:	learn: 0.9402707	total: 854ms	remaining: 238ms
# 782:	learn: 0.9400588	total: 854ms	remaining: 237ms
# 783:	learn: 0.9399236	total: 855ms	remaining: 236ms
# 784:	learn: 0.9396430	total: 856ms	remaining: 235ms
# 785:	learn: 0.9394312	total: 858ms	remaining: 233ms
# 786:	learn: 0.9393743	total: 859ms	remaining: 232ms
# 787:	learn: 0.9392464	total: 860ms	remaining: 231ms
# 788:	learn: 0.9390738	total: 861ms	remaining: 230ms
# 789:	learn: 0.9388976	total: 862ms	remaining: 229ms
# 790:	learn: 0.9387035	total: 863ms	remaining: 228ms
# 791:	learn: 0.9385895	total: 864ms	remaining: 227ms
# 792:	learn: 0.9383432	total: 865ms	remaining: 226ms
# 793:	learn: 0.9380825	total: 866ms	remaining: 225ms
# 794:	learn: 0.9380724	total: 867ms	remaining: 224ms
# 795:	learn: 0.9379626	total: 868ms	remaining: 222ms
# 796:	learn: 0.9378180	total: 869ms	remaining: 221ms
# 797:	learn: 0.9375502	total: 870ms	remaining: 220ms
# 798:	learn: 0.9371803	total: 871ms	remaining: 219ms
# 799:	learn: 0.9370804	total: 872ms	remaining: 218ms
# 800:	learn: 0.9369794	total: 873ms	remaining: 217ms
# 801:	learn: 0.9368124	total: 874ms	remaining: 216ms
# 802:	learn: 0.9366195	total: 875ms	remaining: 215ms
# 803:	learn: 0.9364855	total: 876ms	remaining: 214ms
# 804:	learn: 0.9363494	total: 877ms	remaining: 213ms
# 805:	learn: 0.9361538	total: 878ms	remaining: 211ms
# 806:	learn: 0.9359947	total: 879ms	remaining: 210ms
# 807:	learn: 0.9357581	total: 880ms	remaining: 209ms
# 808:	learn: 0.9355404	total: 881ms	remaining: 208ms
# 809:	learn: 0.9355045	total: 882ms	remaining: 207ms
# 810:	learn: 0.9353443	total: 883ms	remaining: 206ms
# 811:	learn: 0.9351427	total: 884ms	remaining: 205ms
# 812:	learn: 0.9350695	total: 885ms	remaining: 204ms
# 813:	learn: 0.9348661	total: 886ms	remaining: 203ms
# 814:	learn: 0.9348397	total: 887ms	remaining: 201ms
# 815:	learn: 0.9346325	total: 888ms	remaining: 200ms
# 816:	learn: 0.9344174	total: 889ms	remaining: 199ms
# 817:	learn: 0.9341755	total: 890ms	remaining: 198ms
# 818:	learn: 0.9340120	total: 891ms	remaining: 197ms
# 819:	learn: 0.9339782	total: 892ms	remaining: 196ms
# 820:	learn: 0.9339045	total: 893ms	remaining: 195ms
# 821:	learn: 0.9336701	total: 894ms	remaining: 194ms
# 822:	learn: 0.9334884	total: 895ms	remaining: 193ms
# 823:	learn: 0.9333632	total: 896ms	remaining: 191ms
# 824:	learn: 0.9331630	total: 897ms	remaining: 190ms
# 825:	learn: 0.9329873	total: 898ms	remaining: 189ms
# 826:	learn: 0.9329611	total: 899ms	remaining: 188ms
# 827:	learn: 0.9328672	total: 900ms	remaining: 187ms
# 828:	learn: 0.9326251	total: 901ms	remaining: 186ms
# 829:	learn: 0.9325694	total: 902ms	remaining: 185ms
# 830:	learn: 0.9322798	total: 903ms	remaining: 184ms
# 831:	learn: 0.9321709	total: 904ms	remaining: 183ms
# 832:	learn: 0.9320483	total: 905ms	remaining: 182ms
# 833:	learn: 0.9319310	total: 906ms	remaining: 180ms
# 834:	learn: 0.9317347	total: 907ms	remaining: 179ms
# 835:	learn: 0.9317023	total: 908ms	remaining: 178ms
# 836:	learn: 0.9316119	total: 910ms	remaining: 177ms
# 837:	learn: 0.9314989	total: 911ms	remaining: 176ms
# 838:	learn: 0.9312413	total: 912ms	remaining: 175ms
# 839:	learn: 0.9310769	total: 913ms	remaining: 174ms
# 840:	learn: 0.9307099	total: 914ms	remaining: 173ms
# 841:	learn: 0.9304975	total: 915ms	remaining: 172ms
# 842:	learn: 0.9302511	total: 916ms	remaining: 171ms
# 843:	learn: 0.9302419	total: 917ms	remaining: 169ms
# 844:	learn: 0.9299943	total: 918ms	remaining: 168ms
# 845:	learn: 0.9297946	total: 919ms	remaining: 167ms
# 846:	learn: 0.9297672	total: 920ms	remaining: 166ms
# 847:	learn: 0.9297435	total: 921ms	remaining: 165ms
# 848:	learn: 0.9296185	total: 922ms	remaining: 164ms
# 849:	learn: 0.9295587	total: 923ms	remaining: 163ms
# 850:	learn: 0.9293826	total: 924ms	remaining: 162ms
# 851:	learn: 0.9292218	total: 925ms	remaining: 161ms
# 852:	learn: 0.9290122	total: 926ms	remaining: 160ms
# 853:	learn: 0.9288304	total: 927ms	remaining: 159ms
# 854:	learn: 0.9286370	total: 928ms	remaining: 157ms
# 855:	learn: 0.9283090	total: 929ms	remaining: 156ms
# 856:	learn: 0.9281476	total: 931ms	remaining: 155ms
# 857:	learn: 0.9279655	total: 932ms	remaining: 154ms
# 858:	learn: 0.9278688	total: 933ms	remaining: 153ms
# 859:	learn: 0.9277577	total: 934ms	remaining: 152ms
# 860:	learn: 0.9275375	total: 935ms	remaining: 151ms
# 861:	learn: 0.9272905	total: 936ms	remaining: 150ms
# 862:	learn: 0.9271990	total: 937ms	remaining: 149ms
# 863:	learn: 0.9271028	total: 938ms	remaining: 148ms
# 864:	learn: 0.9265492	total: 939ms	remaining: 147ms
# 865:	learn: 0.9263132	total: 940ms	remaining: 145ms
# 866:	learn: 0.9262943	total: 941ms	remaining: 144ms
# 867:	learn: 0.9262051	total: 942ms	remaining: 143ms
# 868:	learn: 0.9258340	total: 943ms	remaining: 142ms
# 869:	learn: 0.9257963	total: 944ms	remaining: 141ms
# 870:	learn: 0.9257458	total: 945ms	remaining: 140ms
# 871:	learn: 0.9257276	total: 946ms	remaining: 139ms
# 872:	learn: 0.9256028	total: 947ms	remaining: 138ms
# 873:	learn: 0.9254605	total: 948ms	remaining: 137ms
# 874:	learn: 0.9252484	total: 949ms	remaining: 136ms
# 875:	learn: 0.9251618	total: 950ms	remaining: 135ms
# 876:	learn: 0.9247282	total: 951ms	remaining: 133ms
# 877:	learn: 0.9247138	total: 953ms	remaining: 132ms
# 878:	learn: 0.9246881	total: 954ms	remaining: 131ms
# 879:	learn: 0.9244814	total: 955ms	remaining: 130ms
# 880:	learn: 0.9242510	total: 956ms	remaining: 129ms
# 881:	learn: 0.9240401	total: 957ms	remaining: 128ms
# 882:	learn: 0.9238894	total: 958ms	remaining: 127ms
# 883:	learn: 0.9237739	total: 959ms	remaining: 126ms
# 884:	learn: 0.9237597	total: 960ms	remaining: 125ms
# 885:	learn: 0.9235452	total: 961ms	remaining: 124ms
# 886:	learn: 0.9233735	total: 963ms	remaining: 123ms
# 887:	learn: 0.9231414	total: 964ms	remaining: 122ms
# 888:	learn: 0.9229423	total: 965ms	remaining: 120ms
# 889:	learn: 0.9227080	total: 966ms	remaining: 119ms
# 890:	learn: 0.9224512	total: 967ms	remaining: 118ms
# 891:	learn: 0.9222496	total: 968ms	remaining: 117ms
# 892:	learn: 0.9221330	total: 969ms	remaining: 116ms
# 893:	learn: 0.9218593	total: 970ms	remaining: 115ms
# 894:	learn: 0.9217165	total: 972ms	remaining: 114ms
# 895:	learn: 0.9215579	total: 973ms	remaining: 113ms
# 896:	learn: 0.9213299	total: 974ms	remaining: 112ms
# 897:	learn: 0.9212771	total: 975ms	remaining: 111ms
# 898:	learn: 0.9211528	total: 976ms	remaining: 110ms
# 899:	learn: 0.9209328	total: 977ms	remaining: 109ms
# 900:	learn: 0.9206602	total: 978ms	remaining: 107ms
# 901:	learn: 0.9205480	total: 979ms	remaining: 106ms
# 902:	learn: 0.9205401	total: 980ms	remaining: 105ms
# 903:	learn: 0.9204091	total: 981ms	remaining: 104ms
# 904:	learn: 0.9201625	total: 982ms	remaining: 103ms
# 905:	learn: 0.9200626	total: 983ms	remaining: 102ms
# 906:	learn: 0.9199732	total: 984ms	remaining: 101ms
# 907:	learn: 0.9198186	total: 986ms	remaining: 99.9ms
# 908:	learn: 0.9197929	total: 987ms	remaining: 98.8ms
# 909:	learn: 0.9194078	total: 988ms	remaining: 97.7ms
# 910:	learn: 0.9192311	total: 989ms	remaining: 96.6ms
# 911:	learn: 0.9190323	total: 990ms	remaining: 95.5ms
# 912:	learn: 0.9188588	total: 991ms	remaining: 94.5ms
# 913:	learn: 0.9185248	total: 992ms	remaining: 93.4ms
# 914:	learn: 0.9183463	total: 993ms	remaining: 92.3ms
# 915:	learn: 0.9182072	total: 994ms	remaining: 91.2ms
# 916:	learn: 0.9180246	total: 995ms	remaining: 90.1ms
# 917:	learn: 0.9178694	total: 996ms	remaining: 89ms
# 918:	learn: 0.9177480	total: 997ms	remaining: 87.9ms
# 919:	learn: 0.9176433	total: 998ms	remaining: 86.8ms
# 920:	learn: 0.9174806	total: 999ms	remaining: 85.7ms
# 921:	learn: 0.9173190	total: 1s	remaining: 84.6ms
# 922:	learn: 0.9172670	total: 1s	remaining: 83.5ms
# 923:	learn: 0.9171343	total: 1s	remaining: 82.4ms
# 924:	learn: 0.9169596	total: 1s	remaining: 81.4ms
# 925:	learn: 0.9169520	total: 1s	remaining: 80.3ms
# 926:	learn: 0.9168455	total: 1s	remaining: 79.2ms
# 927:	learn: 0.9166960	total: 1.01s	remaining: 78.1ms
# 928:	learn: 0.9165855	total: 1.01s	remaining: 77ms
# 929:	learn: 0.9162350	total: 1.01s	remaining: 75.9ms
# 930:	learn: 0.9162146	total: 1.01s	remaining: 74.9ms
# 931:	learn: 0.9160448	total: 1.01s	remaining: 73.8ms
# 932:	learn: 0.9157957	total: 1.01s	remaining: 72.7ms
# 933:	learn: 0.9156231	total: 1.01s	remaining: 71.6ms
# 934:	learn: 0.9154596	total: 1.01s	remaining: 70.5ms
# 935:	learn: 0.9152796	total: 1.01s	remaining: 69.4ms
# 936:	learn: 0.9151615	total: 1.02s	remaining: 68.3ms
# 937:	learn: 0.9148846	total: 1.02s	remaining: 67.2ms
# 938:	learn: 0.9147214	total: 1.02s	remaining: 66.1ms
# 939:	learn: 0.9144976	total: 1.02s	remaining: 65.1ms
# 940:	learn: 0.9142358	total: 1.02s	remaining: 64ms
# 941:	learn: 0.9142159	total: 1.02s	remaining: 62.9ms
# 942:	learn: 0.9140562	total: 1.02s	remaining: 61.8ms
# 943:	learn: 0.9138871	total: 1.02s	remaining: 60.7ms
# 944:	learn: 0.9136963	total: 1.02s	remaining: 59.6ms
# 945:	learn: 0.9134946	total: 1.02s	remaining: 58.5ms
# 946:	learn: 0.9132904	total: 1.03s	remaining: 57.4ms
# 947:	learn: 0.9131129	total: 1.03s	remaining: 56.3ms
# 948:	learn: 0.9128590	total: 1.03s	remaining: 55.3ms
# 949:	learn: 0.9125657	total: 1.03s	remaining: 54.2ms
# 950:	learn: 0.9124332	total: 1.03s	remaining: 53.1ms
# 951:	learn: 0.9123057	total: 1.03s	remaining: 52ms
# 952:	learn: 0.9122886	total: 1.03s	remaining: 50.9ms
# 953:	learn: 0.9121096	total: 1.03s	remaining: 49.8ms
# 954:	learn: 0.9120882	total: 1.03s	remaining: 48.7ms
# 955:	learn: 0.9119542	total: 1.03s	remaining: 47.7ms
# 956:	learn: 0.9119349	total: 1.04s	remaining: 46.6ms
# 957:	learn: 0.9118482	total: 1.04s	remaining: 45.5ms
# 958:	learn: 0.9115834	total: 1.04s	remaining: 44.4ms
# 959:	learn: 0.9112841	total: 1.04s	remaining: 43.3ms
# 960:	learn: 0.9112640	total: 1.04s	remaining: 42.2ms
# 961:	learn: 0.9110700	total: 1.04s	remaining: 41.1ms
# 962:	learn: 0.9110416	total: 1.04s	remaining: 40.1ms
# 963:	learn: 0.9107711	total: 1.04s	remaining: 39ms
# 964:	learn: 0.9106656	total: 1.04s	remaining: 37.9ms
# 965:	learn: 0.9104553	total: 1.04s	remaining: 36.8ms
# 966:	learn: 0.9103640	total: 1.05s	remaining: 35.7ms
# 967:	learn: 0.9103516	total: 1.05s	remaining: 34.6ms
# 968:	learn: 0.9102471	total: 1.05s	remaining: 33.6ms
# 969:	learn: 0.9100083	total: 1.05s	remaining: 32.5ms
# 970:	learn: 0.9098248	total: 1.05s	remaining: 31.4ms
# 971:	learn: 0.9097979	total: 1.05s	remaining: 30.3ms
# 972:	learn: 0.9096569	total: 1.05s	remaining: 29.2ms
# 973:	learn: 0.9095563	total: 1.05s	remaining: 28.1ms
# 974:	learn: 0.9095468	total: 1.05s	remaining: 27ms
# 975:	learn: 0.9094459	total: 1.05s	remaining: 26ms
# 976:	learn: 0.9094231	total: 1.06s	remaining: 24.9ms
# 977:	learn: 0.9092957	total: 1.06s	remaining: 23.8ms
# 978:	learn: 0.9091535	total: 1.06s	remaining: 22.7ms
# 979:	learn: 0.9089461	total: 1.06s	remaining: 21.6ms
# 980:	learn: 0.9089211	total: 1.06s	remaining: 20.6ms
# 981:	learn: 0.9088148	total: 1.06s	remaining: 19.5ms
# 982:	learn: 0.9086041	total: 1.06s	remaining: 18.4ms
# 983:	learn: 0.9085630	total: 1.06s	remaining: 17.3ms
# 984:	learn: 0.9083800	total: 1.06s	remaining: 16.2ms
# 985:	learn: 0.9082005	total: 1.07s	remaining: 15.1ms
# 986:	learn: 0.9080752	total: 1.07s	remaining: 14.1ms
# 987:	learn: 0.9078370	total: 1.07s	remaining: 13ms
# 988:	learn: 0.9078305	total: 1.07s	remaining: 11.9ms
# 989:	learn: 0.9076886	total: 1.07s	remaining: 10.8ms
# 990:	learn: 0.9074154	total: 1.07s	remaining: 9.73ms
# 991:	learn: 0.9072229	total: 1.07s	remaining: 8.65ms
# 992:	learn: 0.9070945	total: 1.07s	remaining: 7.57ms
# 993:	learn: 0.9069348	total: 1.07s	remaining: 6.49ms
# 994:	learn: 0.9067816	total: 1.07s	remaining: 5.4ms
# 995:	learn: 0.9067702	total: 1.08s	remaining: 4.32ms
# 996:	learn: 0.9066234	total: 1.08s	remaining: 3.24ms
# 997:	learn: 0.9064440	total: 1.08s	remaining: 2.16ms
# 998:	learn: 0.9062909	total: 1.08s	remaining: 1.08ms
# 999:	learn: 0.9062108	total: 1.08s	remaining: 0us

# %%
# 예측
# 학습 데이터에 대한 예측
y_pred_train = cat.predict(X_train)
# 테스트 데이터에 대한 예측
y_pred_test = cat.predict(X_test)

# 평가
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# 훈련 데이터 성능 지표 계산
mse_train = mean_squared_error(y_train, y_pred_train)
rmse_train = np.sqrt(mse_train)
mae_train = mean_absolute_error(y_train, y_pred_train)
r2_train = r2_score(y_train, y_pred_train)
# 테스트 데이터 성능 지표 계산
mse_test = mean_squared_error(y_test, y_pred_test)
rmse_test = np.sqrt(mse_test)
mae_test = mean_absolute_error(y_test, y_pred_test)
r2_test = r2_score(y_test, y_pred_test)
# 결과 출력
print("--- Training Set Performance ---")
print(f"MSE: {mse_train:.4f}")
print(f"RMSE: {rmse_train:.4f}")
print(f"MAE: {mae_train:.4f}")
print(f"R² Score: {r2_train:.4f}\n")
print("--- Test Set Performance ---")
print(f"MSE: {mse_test:.4f}")
print(f"RMSE: {rmse_test:.4f}")
print(f"MAE: {mae_test:.4f}")
print(f"R² Score: {r2_test:.4f}")
# Out:
# --- Training Set Performance ---
# MSE: 0.8212
# RMSE: 0.9062
# MAE: 0.6831
# R² Score: 0.6413
#
# --- Test Set Performance ---
# MSE: 1.1874
# RMSE: 1.0897
# MAE: 0.7989
# R² Score: 0.4924

# %% [markdown]
# # 피처 중요도 확인

# %%
# 피쳐 중요도 확인
feature_importances = RF.feature_importances_
feature_names = data.drop("PHI_BENEFIT", axis=1).columns

# 피쳐 중요도를 데이터프레임으로 정리
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# 결과 출력
print(importance_df)
# Out:
#           Feature  Importance
# 28         H_INC7    0.659365
# 114           AGE    0.092056
# 130     INMED_CNR    0.075166
# 20          H_OOP    0.053306
# 119       OOP_TOT    0.014406
# ..            ...         ...
# 121      CARE_TOT    0.000000
# 122         WT_MG    0.000000
# 8        PHI4_4_D    0.000000
# 72   DISA_TY_13.0    0.000000
# 158  OUORT_DZ_9.0    0.000000
#
# [159 rows x 2 columns]

# %%
importance_df_head = importance_df.head(10)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 7))
plt.barh(importance_df_head["Feature"], importance_df_head["Importance"])
plt.show()
